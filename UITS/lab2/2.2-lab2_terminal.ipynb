# %% [markdown]
# [previous](2-linux_lab2_index.ipynb)

# %% [markdown]
# ```bash
#
# labex:project/ $ pwd
# /home/labex/project
# labex:project/ $
# labex:project/ $ ls
# UITS  cd_test  saraf
# labex:project/ $
# labex:project/ $ ls -l
# total 0
# drwxr-xr-x 5 labex labex 49 Feb  3 11:03 UITS
# drwxrwxr-x 2 labex labex 26 Feb  3 10:46 cd_test
# drwxrwxr-x 2 labex labex  6 Feb  3 10:40 saraf
# labex:project/ $ cd /home/labex/project/UITS
# labex:UITS/ $ pwd
# /home/labex/project/UITS
# labex:UITS/ $
# labex:UITS/ $ cd /home/labex/project/UITS/Commerce
# labex:Commerce/ $ mkdir MBA
# labex:Commerce/ $ pwd
# /home/labex/project/UITS/Commerce
# labex:Commerce/ $ ls
# BBA  MBA
# labex:Commerce/ $ cd /home/labex/project/
# labex:project/ $ ls
# UITS  cd_test  saraf
# labex:project/ $ cd /home/labex/project/saraf
# labex:saraf/ $ touch temp_file.txt
# labex:saraf/ $ "some random text" > temp_file.txt
# zsh: command not found: some random text
# labex:saraf/ $ echo "some random text" > temp_file.txt
# labex:saraf/ $ cat temp_file.txt
# some random text
# labex:saraf/ $ cat > temp_file.txt
# 2nd line
# 3rd line
# saved with ctrl+D
# labex:saraf/ $ nano temp_file.txt
# labex:saraf/ $
# ```
