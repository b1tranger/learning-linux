# %% [markdown]
# # # Lab 2 Report: To write a report on Linux Programming Lab-2 and Lab Tasks
# - Introduction
# - Details about today classes
# - Lab Tasks with solution (create it in your own pc and take screenshot of code and files...)

# %% [markdown]
# <br><br>

# %% [markdown]
# <h1 align=center>Introduction</h1>
# <hr>
#
# Linux is a Unix-based Operating System that is widely deemed as a good alternative to Windows Operating System.

# %% [markdown]
# <h1 align=center>Details of Lab-2</h1>
# <hr>
#
# In Lab-2, we learned about some basic Linux Commands (using Bash in Shell) like:
#
# - “mkdir <subfolder folder name>” &rarr; used to make directory
# - “rmdir” &rarr; remote directory
# - “pwd” &rarr; present working directory
# - “cd <path/folder name>” &rarr; change directory
# - “ls” &rarr; list subdirectories
#
# We conducted the lab using a web virtual machine at https://labex.io/labs/

# %% [markdown]
# <h1 align=center>Lab Task</h1>
# <hr>
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# <h1 align=center>Solution</h1>
# <hr>
#
#  ![image.png](data:image/png;base64,...)
#
#  ![image.png](data:image/png;base64,...)
#
#  ![image.png](data:image/png;base64,...)
#
#  ![image.png](data:image/png;base64,...)
#
#  ![image.png](data:image/png;base64,...)
#
#  ![image.png](data:image/png;base64,...)

# %% [markdown]
# <h1 align=center>Conclusions</h1>
# <hr>
#
# We successfully completed the tasks given to us in the lab.
