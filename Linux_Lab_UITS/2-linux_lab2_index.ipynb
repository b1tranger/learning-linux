# %% [markdown]
# [previous](0-linux_lab_index.ipynb) | next
#
# - [2.1-linux_commands](2.1-linux_commands.ipynb)
# - [2.2-lab2_terminal.ipynb](2.2-lab2_terminal.ipynb)
# - [Lab_Report_2.ipynb](reports/Lab_Report_2.ipynb)

# %% [markdown]
# <h1 align=center>task</h1>
#
# goal: using `mkdir` to create the file structure
#
# using https://labex.io/labs/ since Linux is not installed on Lab computers
#
# ![image.png](attachment:image.png)
