# %% [markdown]
# [previous](0-linux_lab_index.ipynb) | [next](2-linux_lab2_index.ipynb)
#
# - [1.1-what-is-shell-programming.ipynb](1.1-what-is-shell-programming.ipynb)
# - [1.2-what-is-kernel.ipynb](1.2-what-is-kernel.ipynb)
